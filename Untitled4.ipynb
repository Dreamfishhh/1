# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from skopt import BayesSearchCV
import matplotlib.pyplot as plt

# %% [markdown]
# # 一、数据预处理

# %%
# Load the data导入数据
data = pd.read_csv("D:\\HuaweiMoveData\\Users\\86178\\Desktop\\Dataset of Diabetes2.csv")  # Replace with your dataset path
data
# Out:
#       ID  No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317       1   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534       1   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654       1   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004       1   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054       1   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI  CLASS
# 0    24.0      0
# 1    23.0      0
# 2    24.0      0
# 3    24.0      0
# 4    21.0      0
# ..    ...    ...
# 995  30.0      2
# 996  37.2      2
# 997  27.4      2
# 998  40.5      2
# 999  33.0      2
#
# [1000 rows x 14 columns]

# %% [markdown]
# ## 1.1属性转化：这里我已经在原始数据表格里把性别Gender类“M”改为1，“F”改为“0”；CLASS类N:2 P:1 Y:0

# %%
# 提取需要的特征列，X是除了ID、No_Pation以外的11个指标
features =data.columns[2:13].tolist()  
X = data[features]
y = data['CLASS']

# %% [markdown]
# ## 1.2标准化处理：对11个指标作“标准化”处理
# ### 除了用“标准化”，也可以用“规范化”，后面看看要不要作对比！（对比点①）

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # 二、特征筛选：MRMR方法选10个最优指标
# ### 这里先使用MRMR方法，也可用ICA或PCA（对比点②）

# %%
# Step 2: Feature Selection with MRMR
def mrmr_feature_selection(X, y, k=10):
    selector = SelectKBest(score_func=mutual_info_classif, k=k)
    X_new = selector.fit_transform(X, y)
    selected_features = selector.get_support(indices=True)
    return X_new, selected_features

X_selected, selected_features = mrmr_feature_selection(X_scaled, y, k=10)
print("Selected features:", X.columns[selected_features])
# Out:
# Selected features: Index(['AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL',
#        'BMI'],
#       dtype='object')

# %% [markdown]
# # 三、通过贝叶斯优化和k折交叉验证，对随机森林RF进行超参数调优
# ### 寻找最优超参数也可用“网格搜索”（对比点③）
# ### 算法模型也可用k-NN、SVM、DT、AdaBoost 和 GNB等等（对比点④）

# %%
# Define the random forest classifier
rf = RandomForestClassifier(random_state=42)

# Define the hyperparameter search space
search_space = {
    'n_estimators': (10, 200),
    'max_depth': (5, 30),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 10)
}

# Define BayesSearchCV
bayes_cv = BayesSearchCV(
    estimator=rf,
    search_spaces=search_space,
    cv=KFold(n_splits=5, shuffle=True, random_state=42),
    n_iter=30,  # Number of parameter combinations to test
    scoring='accuracy',
    random_state=42
)

# Perform hyperparameter tuning
bayes_cv.fit(X_selected, y)
best_rf = bayes_cv.best_estimator_
print("Best Parameters:", bayes_cv.best_params_)
# Out:
# Best Parameters: OrderedDict([('max_depth', 30), ('min_samples_leaf', 4), ('min_samples_split', 10), ('n_estimators', 45)])

# %% [markdown]
# # 四、划分训练集和测试集，并训练模型

# %%
# Step 4: Train-Test Split and Model Training
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
best_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=30, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=45, random_state=42)

# %% [markdown]
# # 五、模型评估：计算平均准确率、精确率、召回率、F1 分数、ROC和 AUC 值来评估模型对测试集的预测效果

# %%
# Step 5: Model Evaluation
y_pred = best_rf.predict(X_test)
y_prob = best_rf.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
roc_auc = roc_auc_score(pd.get_dummies(y_test), pd.get_dummies(y_pred), multi_class="ovr")

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

# ROC Curve
fpr = {}
tpr = {}
for i in range(3):  # Three classes
    fpr[i], tpr[i], _ = roc_curve(pd.get_dummies(y_test).iloc[:, i], pd.get_dummies(y_pred).iloc[:, i])

plt.figure()
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Accuracy: 0.9850
# Precision: 0.9848
# Recall: 0.9850
# F1 Score: 0.9848
# ROC AUC: 0.9699
